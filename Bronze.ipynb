# %%
last_load_date = '2000-01-01'

# %%
spark.sql(f"""Select * from datamodelling_vasu.default.source_data 
          where order_date > '{last_load_date}'""").createOrReplaceTempView("bronze_source")

# %%
# %sql
select * from bronze_source;

# %%
# %sql
CREATE OR REPLACE TABLE datamodelling_vasu.bronze.bronze_table
AS
SELECT * FROM bronze_source

# %%
result_df = spark.sql("""SELECT * FROM datamodelling_vasu.bronze.bronze_table""")

# %%
result_df.display()

# %% [markdown]
# #### Dynamic Loading

# %%
if spark.catalog.tableExists("datamodelling_vasu.bronze.bronze_table"):
    last_load_date = spark.sql("select max(order_date) from datamodelling_vasu.bronze.bronze_table").collect()[0][0]
else:
    last_load_date = '2000-01-01'

# %%
last_load_date

# %%
spark.sql(f"""Select * from datamodelling_vasu.default.source_data 
          where order_date > '{last_load_date}'""").createOrReplaceTempView("bronze_source")

# %%
# %sql
select * from bronze_source;

# %%
# %sql
CREATE OR REPLACE TABLE datamodelling_vasu.bronze.bronze_table
AS
SELECT * FROM bronze_source
