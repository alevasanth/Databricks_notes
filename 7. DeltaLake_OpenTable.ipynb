# %% [markdown]
# #### DELTA LAKE WITH SparkSql

# %%
# %sql
SELECT * FROM 
spark_sql.ecommerce.ecommerce_orders

# %%
# %sql
DESCRIBE spark_sql.ecommerce.ecommerce_orders

# %%
# %sql
DESCRIBE EXTENDED spark_sql.ecommerce.ecommerce_orders

# %% [markdown]
# ### Data Versioning

# %%
# %sql
delete from spark_sql.ecommerce.ecommerce_orders where order_id = 1005

# %%
# %sql
delete from spark_sql.ecommerce.ecommerce_orders

# %%
# %sql
Describe History spark_sql.ecommerce.ecommerce_orders

# %% [markdown]
# ### Time Travel

# %%
# %sql
RESTORE spark_sql.ecommerce.ecommerce_orders TO VERSION AS OF 1

# %%
# %sql
select * from spark_sql.ecommerce.ecommerce_orders

# %%
# %sql
UPDATE spark_sql.ecommerce.ecommerce_orders
SET product_name = 'Wall Frame'
where product_name = 'Photo Frame';

# %%
# %sql
Delete from spark_sql.ecommerce.ecommerce_orders
where order_id between 1040 and 1050

# %%
# %sql
Describe History spark_sql.ecommerce.ecommerce_orders

# %%
# %sql
RESTORE spark_sql.ecommerce.ecommerce_orders TO VERSION AS OF 5

# %%
# %sql
select * from spark_sql.ecommerce.ecommerce_orders

# %%
# %sql
DESCRIBE EXTENDED spark_sql.ecommerce.ecommerce_orders

# %% [markdown]
# #### Restore delta tables

# %%
# %sql
DESCRIBE HISTORY delta.'abfss://filepath'

# %%
# %sql
RESTORE delta.'abfss://filepath'
to version as of 0
