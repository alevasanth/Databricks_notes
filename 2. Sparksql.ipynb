# %%
# %sql
Select * from spark_sql.ecommerce.ecomm_orders;

# %%
# %sql
select * from spark_sql.ecommerce.ecomm_orders
WHERE product_category='Fashion';

# %%
df_filter = spark.sql('''select * from spark_sql.ecommerce.ecomm_orders
WHERE product_category="Fashion";''')

# %%
df_filter.display()
