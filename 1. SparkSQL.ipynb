# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/spark_sql/source/ecommerce")
display(df)

# %%
df.display()

# %%
df.show()

# %% [markdown]
# ### Spark SQL
# #### 1. Temp View

# %%
df.createOrReplaceTempView("ecommerce_temp")
df.printSchema()
df.count()

# %%
# %sql
select * from ecommerce_temp;

# %%
df.createOrReplaceGlobalTempView("ecommerce_global")

# %%
# %sql
select * from GlobalTemp ecommerce_temp;

# %% [markdown]
# ### External vs Managed Tables

# %%
# %sql
create schema spark_sql.ecommerce

# %%
# %sql
Create or replace table spark_sql.ecommerce.ecomm_orders 
as 
select * from ecommerce_temp;

# %%
# %sql
select * from spark_sql.ecommerce.ecomm_orders

# %%
# %sql
DROP TABLE spark_sql.ecommerce.ecomm_orders

# %%
# %sql
UNDROP TABLE spark_sql.ecommerce.ecomm_orders

# %% [markdown]
# ### EXternal Table

# %%
# %sql
Create table spark_sql.ecommerce.ecomm_orders_ext
Location 'dbfs:/Volumes/spark_sql/ecommerce/ecomm_orders_ext'
as 
select * from ecommerce_temp;
